# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd

# Load the dataset
data = load_breast_cancer()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] = data.target  # Add the target column (benign=0, malignant=1)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot target distribution
sns.countplot(x='target', data=df)
plt.title('Distribution of Target (Benign vs Malignant)')
plt.show()

# %%
# Correlation matrix
corr_matrix = df.corr()

# Heatmap of correlations
plt.figure(figsize=(15, 10))
sns.heatmap(corr_matrix, annot=False, fmt='.2f', cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# Plot histograms for a few important features
df[['mean radius', 'mean texture', 'mean perimeter', 'mean area']].hist(bins=20, figsize=(12, 8))
plt.tight_layout()
plt.show()b

# %%
# KDE plots for features
sns.kdeplot(df['mean radius'], label='Mean Radius', fill=True)
sns.kdeplot(df['mean area'], label='Mean Area', fill=True)
plt.title('Density Plot for Mean Radius and Mean Area')
plt.show()
